# %%
# exercicio 1
import pandas as pd

#1. carregar os dados do arquivo
df = pd.read_excel('dados_ausentes.xlsx')
print(df.head(5))
# Out:
#     Nome  Idade          Cidade  Salário
# 0   João   28.0       São Paulo   3500.0
# 1  Maria    NaN  Rio de Janeiro   4500.0
# 2   José   35.0             NaN      NaN
# 3    Ana   22.0        Salvador   5000.0
# 4  Pedro    NaN    Porto Alegre   4800.0

# %%
# exercicio 2 

print(df.isnull().sum())
print(df.isnull())
# Out:
# Nome       0
# Idade      2
# Cidade     1
# Salário    1
# dtype: int64
#     Nome  Idade  Cidade  Salário
# 0  False  False   False    False
# 1  False   True   False    False
# 2  False  False    True     True
# 3  False  False   False    False
# 4  False   True   False    False
# 5  False  False   False    False
# 6  False  False   False    False
# 7  False  False   False    False

# %%
# exercicio 3

df['Idade'].fillna(0, inplace=True)
print(df)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       SÃO PAULO   3500.0
# 1    Maria   35.0  RIO DE JANEIRO   4500.0
# 2     José   35.0             NaN      NaN
# 3      Ana   22.0        SALVADOR   5000.0
# 4    Pedro   20.0    PORTO ALEGRE   4800.0
# 6  Jessica   20.0       SÃO PAULO   3410.0
# 7   Carlos   35.0    PORTO ALEGRE   2500.0
# C:\Users\46492449860\AppData\Local\Temp\ipykernel_18720\1508917473.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Idade'].fillna(0, inplace=True)

# %%
# exercicio 4

df['Idade'].fillna(df['Idade'].mean(), inplace=True)
print(df)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       SÃO PAULO   3500.0
# 1    Maria   35.0  RIO DE JANEIRO   4500.0
# 2     José   35.0             NaN      NaN
# 3      Ana   22.0        SALVADOR   5000.0
# 4    Pedro   20.0    PORTO ALEGRE   4800.0
# 6  Jessica   20.0       SÃO PAULO   3410.0
# 7   Carlos   35.0    PORTO ALEGRE   2500.0
# C:\Users\46492449860\AppData\Local\Temp\ipykernel_18720\4246482950.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Idade'].fillna(df['Idade'].mean(), inplace=True)

# %%
# exercico 5 

dfSemNulos = df.dropna()
print(dfSemNulos)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       SÃO PAULO   3500.0
# 1    Maria   35.0  RIO DE JANEIRO   4500.0
# 3      Ana   22.0        SALVADOR   5000.0
# 4    Pedro   20.0    PORTO ALEGRE   4800.0
# 6  Jessica   20.0       SÃO PAULO   3410.0
# 7   Carlos   35.0    PORTO ALEGRE   2500.0

# %%
# exercicio 6 

df = df.dropna(subset=['Cidade'])
print(df)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       SÃO PAULO   3500.0
# 1    Maria   35.0  RIO DE JANEIRO   4500.0
# 3      Ana   22.0        SALVADOR   5000.0
# 4    Pedro   20.0    PORTO ALEGRE   4800.0
# 6  Jessica   20.0       SÃO PAULO   3410.0
# 7   Carlos   35.0    PORTO ALEGRE   2500.0

# %%
# exercicio 7

df['Salário'].fillna(df['Salário'].median(), inplace=True)
print(df)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       SÃO PAULO   3500.0
# 1    Maria   35.0  RIO DE JANEIRO   4500.0
# 3      Ana   22.0        SALVADOR   5000.0
# 4    Pedro   20.0    PORTO ALEGRE   4800.0
# 6  Jessica   20.0       SÃO PAULO   3410.0
# 7   Carlos   35.0    PORTO ALEGRE   2500.0
# C:\Users\46492449860\AppData\Local\Temp\ipykernel_18720\2208284364.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salário'].fillna(df['Salário'].median(), inplace=True)
# C:\Users\46492449860\AppData\Local\Temp\ipykernel_18720\2208284364.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salário'].fillna(df['Salário'].median(), inplace=True)

# %%
# exercico 8 

df['Salário'].fillna(df['Idade'], inplace=True)
print(df)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       SÃO PAULO   3500.0
# 1    Maria   35.0  RIO DE JANEIRO   4500.0
# 3      Ana   22.0        SALVADOR   5000.0
# 4    Pedro   20.0    PORTO ALEGRE   4800.0
# 6  Jessica   20.0       SÃO PAULO   3410.0
# 7   Carlos   35.0    PORTO ALEGRE   2500.0
# C:\Users\46492449860\AppData\Local\Temp\ipykernel_18720\2902545576.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salário'].fillna(df['Idade'], inplace=True)
# C:\Users\46492449860\AppData\Local\Temp\ipykernel_18720\2902545576.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salário'].fillna(df['Idade'], inplace=True)

# %%
#exercicio 9

df['Idade'].fillna(df['Idade'].ffill(), inplace=True)
print(df)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       SÃO PAULO   3500.0
# 1    Maria   35.0  RIO DE JANEIRO   4500.0
# 3      Ana   22.0        SALVADOR   5000.0
# 4    Pedro   20.0    PORTO ALEGRE   4800.0
# 6  Jessica   20.0       SÃO PAULO   3410.0
# 7   Carlos   35.0    PORTO ALEGRE   2500.0
# C:\Users\46492449860\AppData\Local\Temp\ipykernel_18720\379529454.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Idade'].fillna(df['Idade'].ffill(), inplace=True)
# C:\Users\46492449860\AppData\Local\Temp\ipykernel_18720\379529454.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Idade'].fillna(df['Idade'].ffill(), inplace=True)

# %%
#exercicio 10

df['Idade'].fillna(df['Idade'].bfill(), inplace=True)
print(df)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       SÃO PAULO   3500.0
# 1    Maria   35.0  RIO DE JANEIRO   4500.0
# 3      Ana   22.0        SALVADOR   5000.0
# 4    Pedro   20.0    PORTO ALEGRE   4800.0
# 6  Jessica   20.0       SÃO PAULO   3410.0
# 7   Carlos   35.0    PORTO ALEGRE   2500.0
# C:\Users\46492449860\AppData\Local\Temp\ipykernel_18720\193509440.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Idade'].fillna(df['Idade'].bfill(), inplace=True)
# C:\Users\46492449860\AppData\Local\Temp\ipykernel_18720\193509440.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Idade'].fillna(df['Idade'].bfill(), inplace=True)

# %%
#exercicio 11

df['Cidade'] = df['Cidade'].str.upper()
print(df)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       SÃO PAULO   3500.0
# 1    Maria    NaN  RIO DE JANEIRO   4500.0
# 2     José   35.0             NaN      NaN
# 3      Ana   22.0        SALVADOR   5000.0
# 4    Pedro    NaN    PORTO ALEGRE   4800.0
# 6  Jessica   20.0       SÃO PAULO   3410.0
# 7   Carlos   35.0    PORTO ALEGRE   2500.0

# %%
#exercicio 12

df['Cidade'] = df['Cidade'].str.lower()
print(df)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       são paulo   3500.0
# 1    Maria    NaN  rio de janeiro   4500.0
# 2     José   35.0             NaN      NaN
# 3      Ana   22.0        salvador   5000.0
# 4    Pedro    NaN    porto alegre   4800.0
# 6  Jessica   20.0       são paulo   3410.0
# 7   Carlos   35.0    porto alegre   2500.0

# %%
#exercicio 13

df['Cidade'] = df['Cidade'].str.strip()
print(df)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       São Paulo   3500.0
# 1    Maria    NaN  Rio de Janeiro   4500.0
# 2     José   35.0             NaN      NaN
# 3      Ana   22.0        Salvador   5000.0
# 4    Pedro    NaN    Porto Alegre   4800.0
# 6  Jessica   20.0       são paulo   3410.0
# 7   Carlos   35.0    porto alegre   2500.0

# %%
#exercicio 14

df['Cidade'].str.lower().replace({'são paulo': 'SP', 'rios de janeiro': 'RJ', 'rj': 'RJ', 'sp': 'SP'})
print(df)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       São Paulo   3500.0
# 1    Maria    NaN  Rio de Janeiro   4500.0
# 2     José   35.0             NaN      NaN
# 3      Ana   22.0        Salvador   5000.0
# 4    Pedro    NaN    Porto Alegre   4800.0
# 6  Jessica   20.0      são paulo    3410.0
# 7   Carlos   35.0    porto alegre   2500.0

# %%
#exercicio 15

df = df.drop_duplicates(subset=['Nome'])
print(df)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       São Paulo   3500.0
# 1    Maria    NaN  Rio de Janeiro   4500.0
# 2     José   35.0             NaN      NaN
# 3      Ana   22.0        Salvador   5000.0
# 4    Pedro    NaN    Porto Alegre   4800.0
# 6  Jessica   20.0      são paulo    3410.0
# 7   Carlos   35.0    porto alegre   2500.0
